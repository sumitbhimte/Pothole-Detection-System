# %%
import numpy as np
import pandas as pd
import sqlalchemy as sq

# %%
s=pd.read_csv(r"C:\Users\hrish\Pothole\input.csv")

# %%
s.head()
# Out:
#    ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                   1.889                   0.182                  9.8497
# 1                   1.889                   0.182                  9.8497
# 2                   1.889                   0.182                  9.8497
# 3                   1.889                   0.182                  9.8497
# 4                   1.889                   0.182                  9.8497
#
#    GRAVITY X (m/s²)  GRAVITY Y (m/s²)  GRAVITY Z (m/s²)  \
# 0             2.539            0.2313            9.4694
# 1             2.539            0.2313            9.4694
# 2             2.539            0.2313            9.4694
# 3             2.539            0.2313            9.4694
# 4             2.539            0.2313            9.4694
#
#    LINEAR ACCELERATION X (m/s²)  LINEAR ACCELERATION Y (m/s²)  \
# 0                       -0.0468                       -0.0784
# ...

# %%
sa=s.iloc[:,[0,1,2,22,21]]

# %%
sa.rename(columns = {'ACCELEROMETER X (m/s²)':'AccX', 'ACCELEROMETER Y (m/s²)':'AccY','ACCELEROMETER Z (m/s²)':'AccZ','LOCATION Longitude : ':'Longitude','LOCATION Latitude : ':'Latitude'}, inplace = True)
sa.head()
# Out:
# c:\users\hrish\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     AccX   AccY    AccZ  Longitude  Latitude
# 0  1.889  0.182  9.8497  77.742065  21.23045
# 1  1.889  0.182  9.8497  77.742065  21.23045
# 2  1.889  0.182  9.8497  77.742065  21.23045
# 3  1.889  0.182  9.8497  77.742065  21.23045
# 4  1.889  0.182  9.8497  77.742065  21.23045

# %%
con = sq.create_engine("mysql+pymysql://root:hh1911@localhost/pothole")

# %%
sa.to_sql('potholedata',con)

# %%
sa = pd.read_sql('pot2',con)

# %%
sa.to_csv('new_cleaned.csv')
